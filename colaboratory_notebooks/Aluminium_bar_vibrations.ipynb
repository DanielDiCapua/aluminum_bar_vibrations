# %%
# !pip install sopy_fem
# Out:
# Requirement already satisfied: sopy_fem in /usr/local/lib/python3.12/dist-packages (1.1.0)

# %%
from sopy_fem.sopy_fem_help import sopy_fem_help
from sopy_fem.sopy_fem_run import sopy_fem_run

# %%
sopy_fem_help("dynamics_FRAME02", outputFile="frame02_dynamics.json")

# %%
sopy_fem_run("frame02_dynamics.json")
